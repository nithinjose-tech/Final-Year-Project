# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/(DUC 2002 A)Input Files/DUC 2002 Abstractive.csv')

# %%
data={'index':[],
      'file':[],
      'doc':[],
      'doc_dump':[],
      '1_10':[],
      '1_50':[],
      '1_100':[],
      '1_200':[],
      '2_10':[],
      '2_50':[],
      '2_100':[], 
      '2_200':[],
      '3_10':[],
      '3_50':[],
      '3_100':[],
      '3_200':[]    
}

# %%
for i in range(20):
  str=df.iloc[i][2].replace('\n'," ").replace('\r',"").replace("''","").replace("``","").replace("_","").replace('   ',"").replace("BFN  [Text]","")

  data['index'].append(df.iloc[i][0])
  data['file'].append(df.iloc[i][1])
  data['doc'].append(str)
  data['doc_dump'].append(df.iloc[i][3])
  data['1_10'].append(df.iloc[i][7])
  data['1_50'].append(df.iloc[i][6])
  data['1_100'].append(df.iloc[i][5])
  data['1_200'].append(df.iloc[i][4])
  data['2_10'].append(df.iloc[i][8])
  data['2_50'].append(df.iloc[i][10])
  data['2_100'].append(df.iloc[i][9])
  data['2_200'].append(df.iloc[i][11])
  data['3_10'].append(df.iloc[i][15])
  data['3_50'].append(df.iloc[i][13])
  data['3_100'].append(df.iloc[i][14])
  data['3_200'].append(df.iloc[i][12])

# %%
for i in range(20,59):
  str=df.iloc[i][2].replace('\n',"").replace('\r',"").replace("''","").replace("``","").replace("_","").replace('   ',"").replace("BFN  [Text]","")

  data['index'].append(df.iloc[i][0])
  data['file'].append(df.iloc[i][1])
  data['doc'].append(str)
  data['doc_dump'].append(df.iloc[i][3])
  data['1_10'].append(df.iloc[i][7])
  data['1_50'].append(df.iloc[i][6])
  data['1_100'].append(df.iloc[i][5])
  data['1_200'].append(df.iloc[i][4])
  data['2_10'].append(df.iloc[i][8])
  data['2_50'].append(df.iloc[i][10])
  data['2_100'].append(df.iloc[i][9])
  data['2_200'].append(df.iloc[i][11])
  data['3_10'].append(df.iloc[i][15])
  data['3_50'].append(df.iloc[i][13])
  data['3_100'].append(df.iloc[i][14])
  data['3_200'].append(df.iloc[i][12])

# %%
d = pd.DataFrame.from_dict(data)
d.set_index('index',inplace = True)
d.sort_index(ascending=True, inplace=True)

# %%
print(data['doc'][6])
# Out:
#  Buenos Aires, 23 May (NA) -- Today, the Foreign  Ministry said that control operations carried out by the  corvette Spiro against a Korean-flagged [as received] ship  fishing illegally in Argentine waters were carried out "in  accordance with international law and in coordination with the  Foreign Ministry." The Foreign Ministry thus approved the intervention by the  Argentine corvette when it discovered the Korean ship Chin Yuan  Hsing violating Argentine jurisdictional waters on 21 May. The Argentine Navy reported today that the corvette Spiro  stayed near the Korean ship "given the adverse weather  conditions, and fulfilling its responsibilities of sea search  and rescue." The Korean ship, which had been fishing illegally in  Argentine waters, was sunk by its own crew after failing to  answer to the Argentine ship's warnings. The crew was transferred to the Chin Chuan Hsing, which was  sailing nearby and approached to rescue the crew of the sinking  ship. The Navy reported that a
# ...

# %%
d.head(59)
# Out:
#         file                                                doc  \
# index
# 0      d116i  Five astronauts boarded Discovery today for a ...
# 1      d113h  INDIA suffered a fresh wave of terror last nig...
# 2      d120i  THE revelation that John Major is capable of c...
# 3      d117i  Japanese writer Kazuo Ishiguro won the 1989 Bo...
# 4      d114h  Tens of thousands of people chanting Freedom! ...
# 5      d112h  DOCUMENTS which show for the first time that b...
# 6      d111h   Buenos Aires, 23 May (NA) -- Today, the Forei...
# 7      d118i  John G. Tower has fallen, but the sky has not....
# 8      d119i  President Bush is expected to name a female ca...
# 9      d115i  Police bulldozed unstable brick and mud houses...
# 10     d102e  The actor who played Little Ricky on the I Lov...
# 11     d108g  Hitting Baghdad where it hurts, more countries...
# 12     d103g  Iran is deliberately underreporting the number...
# ...

# %%
d.to_csv('/content/drive/MyDrive/(DUC 2002 A)Input Files/DUC 2002 Abstractive.csv')
